# %%
from keras.models import load_model
# Out:
# Using TensorFlow backend.

# %%
model = load_model('word_kanye_rnn30eps.h5')
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# /anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#
# /anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1316       # Ensure any changes to the graph are reflected in the runtime.
# -> 1317       self._extend_graph()
#    1318       return self._call_tf_sessionrun(
#
# /anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _extend_graph(self)
#    1351     with self._graph._session_run_lock():  # pylint: disable=protected-access
# -> 1352       tf_session.ExtendSession(self._session)
#    1353
#
# ...
